# %% [markdown]
# # Movie Poster Visual Features & Box Office Revenue
#
# **DS 4002 Case Study — Starter Analysis Notebook**
#
# This notebook provides a structured template for your analysis. Follow the TODOs in each section to complete the case study.
#
# ---
#
# ## Research Question
# *Do the visual characteristics of a movie poster predict its worldwide box office performance?*

# %% [markdown]
# ## Part 1: Setup & Data Loading

# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr, spearmanr

# Set styling
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

print('Packages loaded successfully!')

# %%
# Load the pre-extracted poster features dataset
df = pd.read_csv('../DATA/sample_poster_features.csv')

print(f'Dataset shape: {df.shape}')
print(f'Films: {len(df):,}')
print(f'Year range: {df["startYear"].min()} - {df["startYear"].max()}')
df.head()

# %%
# TODO: Explore the dataset
# - Check for missing values with df.isnull().sum()
# - Look at descriptive statistics with df.describe()
# - Examine the distribution of the target variable (log_worldwide)

# YOUR CODE HERE

# %% [markdown]
# ## Part 2: Exploratory Data Analysis (EDA)
#
# **Goal:** Understand the relationships between visual features and box office revenue.

# %%
# TODO: Create a correlation heatmap
# Include all numeric visual features and log_worldwide
# Hint: Use seaborn's heatmap with the annot=True option to show values

# Step 1: Select the columns for correlation
feature_cols = ['avg_brightness', 'avg_saturation', 'orange_teal_score', 
                'face_density', 'log_worldwide']

# Step 2: Compute correlation matrix
# YOUR CODE HERE

# Step 3: Plot heatmap
# YOUR CODE HERE

# %%
# TODO: Report the exact correlation coefficients with log_worldwide
# For each visual feature, compute and print the Pearson correlation and p-value

# Hint: Use scipy.stats.pearsonr(x, y) which returns (correlation, p_value)

# YOUR CODE HERE

# %%
# TODO: Create at least one additional bivariate visualization
# Ideas:
# - Box plot of log_worldwide by release_window
# - Scatter plot of avg_saturation vs. log_worldwide
# - Violin plot comparing face_density across revenue quartiles

# YOUR CODE HERE

# %% [markdown]
# **TODO: Interpret your EDA findings in a few sentences.**
#
# *YOUR INTERPRETATION HERE*

# %% [markdown]
# ## Part 3: Statistical Modeling — Multiple Linear Regression (OLS)
#
# **Goal:** Fit a multiple regression model to determine which visual features are statistically significant predictors of log-transformed worldwide revenue.

# %%
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

# TODO: Prepare the features and target variable
# Step 1: Define your feature columns (visual features + release window dummies)
# Step 2: Create dummy variables for release_window using pd.get_dummies()
# Step 3: Standardize the continuous features with StandardScaler
# Step 4: Define y = df['log_worldwide']

# YOUR CODE HERE

# %%
# TODO: Fit the OLS model and display the summary
# Step 1: Add a constant to X using sm.add_constant()
# Step 2: Fit with sm.OLS(y, X).fit()
# Step 3: Print the model summary

# YOUR CODE HERE

# %% [markdown]
# **TODO: Interpret the OLS results. Address these questions:**
# - What is the R-squared value? What does it mean in this context?
# - Which predictors (if any) are statistically significant at α = 0.05?
# - What do the coefficients tell us about the direction/magnitude of effects?
#
# *YOUR INTERPRETATION HERE*

# %% [markdown]
# ## Part 4: Predictive Modeling — Random Forest
#
# **Goal:** Train a machine learning model and evaluate whether it can predict box office revenue better than the linear model.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# TODO: Train/Test Split and Model Training
# Step 1: Split X and y into 80% train / 20% test with random_state=42
# Step 2: Initialize a RandomForestRegressor (n_estimators=100, random_state=42)
# Step 3: Fit the model on the training data
# Step 4: Make predictions on the test set

# YOUR CODE HERE

# %%
# TODO: Evaluate the Random Forest model
# Step 1: Compute MAE, RMSE, and R-squared on the test set
# Step 2: Print the metrics
# Step 3: Create a feature importance bar chart

# YOUR CODE HERE

# %%
# TODO: Compare OLS vs. Random Forest performance
# Create a summary table comparing R-squared, MAE, and RMSE for both models

# YOUR CODE HERE

# %% [markdown]
# **TODO: Interpret the predictive modeling results. Address:**
# - How did the Random Forest compare to the linear model?
# - Which features were most important according to the Random Forest?
# - What does the R-squared value tell us about the predictability of revenue from visual features?
#
# *YOUR INTERPRETATION HERE*

# %% [markdown]
# ## Part 5: Conclusion
#
# **TODO: Write a conclusion addressing the research question.**
#
# Consider:
# - Do visual poster features predict box office revenue?
# - What are the limitations of this analysis?
# - What factors might be missing that actually drive revenue (marketing budget, franchise IP, star power, etc.)?
# - What would you recommend to the studio?
#
# *YOUR CONCLUSION HERE*
